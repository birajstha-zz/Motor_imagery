# %%
import mne
import numpy as np

# %%
sbj='002'
rec='03'
edf_loc= '/media/biraj/DATA/Motor Imagery Dataset/S'+sbj+'/S'+sbj+'R'+rec+'.edf'
Data = mne.io.read_raw_edf(edf_loc)
events, event_id=mne.events_from_annotations(Data)
epochs=mne.Epochs(Data, events, event_id, tmin=0, tmax=4, baseline=(None,None))
# Out:
# Extracting EDF parameters from /media/biraj/DATA/Motor Imagery Dataset/S002/S002R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# 30 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated

# %% [markdown]
# onset =
# duration =
# desciption =
# my_ann = mne.Annotations(onset, duration, description)

# %%
onset = []
duration = []
description = []

for i in range(len(events)-1):
    if events[i, 2] == 1:
        continue
    elif events[i, 2] == 2:
        print(events[i-1][0])
        onset.append(events[i-1][0])
        duration.append(events[i+1][0]-events[i-1][0])
        description.append('T1')
        continue
    elif events[i, 2] == 3:
        print(events[i-1][0])
        onset.append(events[i-1][0])
        duration.append(events[i+1][0]-events[i-1][0])
        description.append('T2')
        continue
# Out:
# 0
# 1312
# 2624
# 3936
# 5248
# 6560
# 7872
# 9184
# 10496
# 11808
# 13120
# 14432
# 15744
# 17056

# %%
print(onset)
print(np.array(onset)/160)
print(np.array(duration)/160)
# Out:
# [0, 1312, 2624, 3936, 5248, 6560, 7872, 9184, 10496, 11808, 13120, 14432, 15744, 17056]
# [  0.    8.2  16.4  24.6  32.8  41.   49.2  57.4  65.6  73.8  82.   90.2
#   98.4 106.6]
# [8.2 8.2 8.2 8.2 8.2 8.2 8.2 8.2 8.2 8.2 8.2 8.2 8.2 8.2]

# %%
onset = np.array(onset)/160
duration = np.array(duration)/160
my_ann = mne.Annotations(onset, duration, description)
print(my_ann)
# Out:
# <Annotations | 14 segments: T1 (7), T2 (7)>

# %%
Data.set_annotations(my_ann)
# Out:
# <RawEDF | S002R03.edf, 64 x 19680 (123.0 s), ~130 kB, data not loaded>

# %%
events, event_id=mne.events_from_annotations(Data)

epochs=mne.Epochs(Data, events, event_id=event_id,  baseline=(None,None))
# Out:
# Used Annotations descriptions: ['T1', 'T2']
# 14 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated

# %%
T1=epochs['T1']
T2=epochs['T2']

# %%
T1
# Out:
# <Epochs  |   7 events (good & bad), -0.2 - 0.5 sec, baseline [None, None], ~130 kB, data not loaded,
#  'T1': 7>

# %%
montage = mne.channels.make_standard_montage('standard_1020')

# %%
print(montage)
# Out:
# <DigMontage | 0 extras (headshape), 0 HPIs, 3 fiducials, 94 channels>

# %%
fig = montage.plot(kind='3d')
fig.gca().view_init(azim=70, elev=15)
montage.plot(kind='topomap', show_names=True)
# Out:
# 4 duplicate electrode labels found:
# T7/T3, T8/T4, P7/T5, P8/T6
# Plotting 90 unique labels.
# Creating RawArray with float64 data, n_channels=90, n_times=1
#     Range : 0 ... 0 =      0.000 ...     0.000 secs
# Ready.
# 4 duplicate electrode labels found:
# T7/T3, T8/T4, P7/T5, P8/T6
# Plotting 90 unique labels.
# Creating RawArray with float64 data, n_channels=90, n_times=1
#     Range : 0 ... 0 =      0.000 ...     0.000 secs
# Ready.

# %%
Data.rename_channels(lambda x: x.strip('.'))
# Out:
# <RawEDF | S002R03.edf, 64 x 19680 (123.0 s), ~129 kB, data not loaded>

# %%
ch_map = {'Fc5': 'FC5',
          'Fc3': 'FC3',
          'Fc1': 'FC1',
          'Fcz': 'FCz',
          'Fc2': 'FC2',
          'Fc4': 'FC4',
          'Fc6': 'FC6',
          'Cp5': 'CP5',
          'Cp3': 'CP3',
          'Cp1': 'CP1',
          'Cpz': 'CPz',
          'Cp2': 'CP2',
          'Cp4': 'CP4',
          'Cp6': 'CP6',
          'Af7': 'AF7',
          'Af3': 'AF3',
          'Afz': 'AFz',
          'Af4': 'AF4',
          'Af8': 'AF8',
          'Ft7': 'FT7',
          'Ft8': 'FT8',
          'Tp7': 'TP7',
          'Tp8': 'TP8',
          'Po7': 'PO7',
          'Po3': 'PO3',
          'Poz': 'POz',
          'Po4': 'PO4',
          'Po8': 'PO8'}

# %%
Data.rename_channels(ch_map)
# Out:
# <RawEDF | S002R03.edf, 64 x 19680 (123.0 s), ~129 kB, data not loaded>

# %%
Data.set_montage(montage)
# Out:
# <RawEDF | S002R03.edf, 64 x 19680 (123.0 s), ~178 kB, data not loaded>

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
Data.plot_sensors(ch_type='eeg', axes=ax2d)

# %% [markdown]
# Data.plot_sensors('3d')

# %%
epochs_params = dict(events=events, event_id=event_id, tmin=0, tmax=120)

# %%
eeg_ref=mne.Epochs(Data, **epochs_params, baseline=(None, None)).average()
# Out:
# 14 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated

# %%
eeg_ref.plot_topomap(times=np.linspace(1,120,20), size=3., title='Topo_plot', time_unit='s');

# %%
fig = mne.viz.plot_alignment(Data.info, trans=None, dig=False, eeg=True,
                             surfaces=[], meg=['helmet', 'sensors'],
                             coord_frame='eeg')
mne.viz.set_3d_view(fig, azimuth=50, elevation=90, distance=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-dc88f5433689> in <module>
#       1 fig = mne.viz.plot_alignment(Data.info, trans=None, dig=False, eeg=True,
#       2                              surfaces=[], meg=['helmet', 'sensors'],
# ----> 3                              coord_frame='eeg')
#       4 mne.viz.set_3d_view(fig, azimuth=50, elevation=90, distance=0.5)
#
# <decorator-gen-128> in plot_alignment(info, trans, subject, subjects_dir, surfaces, coord_frame, meg, eeg, fwd, dig, ecog, src, mri_fiducials, bem, seeg, fnirs, show_axes, fig, interaction, verbose)
#
# ~/anaconda3/lib/python3.7/site-packages/mne/viz/_3d.py in plot_alignment(info, trans, subject, subjects_dir, surfaces, coord_frame, meg, eeg, fwd, dig, ecog, src, mri_fiducials, bem, seeg, fnirs, show_axes, fig, interaction, verbose)
#     694         is_sphere = True
#     695
# --> 696     _check_option('coord_frame', coord_frame, ['head', 'meg', 'mri'])
#     697     if src is not None:
#     698         src = _ensure_src(src)
#
# ~/anaconda3/lib/python3.7/site-packages/mne/utils/check.py in _check_option(parameter, value, allowed_values, extra)
#     563         options += ' and %r' % allowed_values[-1]
#     564     raise ValueError(msg.format(parameter=parameter, options=options,
# --> 565                                 value=value, extra=extra))
#     566
#     567
#
# ValueError: Invalid value for the 'coord_frame' parameter. Allowed values are 'head', 'meg' and 'mri', but got 'eeg' instead.
